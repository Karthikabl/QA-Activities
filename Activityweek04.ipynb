# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
tdata=pd.read_csv("C:/Users/user/Desktop/Data Science/ACTIVITY/Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv")
tdata
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Compare churn count with respect to gender
plt.figure(figsize=(10, 5))
sns.countplot(tdata['Churn'])
plt.title('Churn count with respect to Gender')
plt.xlabel('Churn')
plt.ylabel('Gender')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Find out how many female senior citizens there in the dataset
bar=np.arange(1)
Fem= tdata[(tdata['SeniorCitizen']==1) & (tdata['gender']=='Female')]
Fem1 = (Fem['SeniorCitizen'].sum())
print('Count of Female Senior Citizen : ', Fem1)
Mal= tdata[(tdata['SeniorCitizen']==1) & (tdata['gender']=='Male')]
Mal1 = (Mal['SeniorCitizen'].sum())
print('Count of Male Senior Citizen : ', Mal1)
plt.bar(bar,Fem1,width=0.50,color='pink', label='Female')
plt.bar(bar+0.50, Mal1,width=0.50,color='blue', label='Male')
plt.legend()
plt.xticks(bar+0.25,['SeniorCitizen'])
plt.ylabel('Females')
plt.title('Female Senior Citizens')
plt.show()
print('There are 568 Female Senior Citizens in the dataset.')
# Out:
# Count of Female Senior Citizen :  568
# Count of Male Senior Citizen :  574
# There are 568 Female Senior Citizens in the dataset

# %%
# Compare 'tenure' with 'Total Charges'
sns.lineplot(data=tdata,x='tenure',y='TotalCharges', color='teal').set(title='Tenure vs Total Charges')
plt.xlabel('Tenure')
plt.ylabel('Total Charges')
plt.show()
print('From the graph, it can be observed that, as tenure is increasing, total charges also increasing.')
# Out:
# From the graph, it can be observed that, as tenure is increasing, total charges also increasing.

# %%
#Find out which contract is preferred by the senior citizen
SC= tdata[(tdata['SeniorCitizen']==1)]
SC = (Fem['SeniorCitizen'].sum())
sns.countplot(x= 'SeniorCitizen',hue='Contract',data=tdata).set(title='Contract preferred by Senior Citizens')
print('Count of Senior Citizens:', SC)
# Out:
# Count of Senior Citizens: 1142

# %%
# Comment on your finds on Payment Method
plt.figure(figsize=(9,7))
sns.countplot(data=tdata, x='PaymentMethod', hue=tdata['gender'])
plt.title('Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()
print('From the graph, it can be concluded that Electronic check is the most used payment method by both the genders.')
# Out:
# From the graph, it can be concluded that Electronic check is the most used payment method by both the genders.
